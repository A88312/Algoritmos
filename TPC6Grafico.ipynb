# %% [markdown]
# ## Manifesto do TPC6
# * **Identificador:** Algoritmos e Técnicas de Programação
# * **Título:** Gráficos de Polinómios
# * **Data de início:** 2021-11-26
# * **Data de fim:** 2021-11-27
# * **Supervisor:** José Carlos Leite Ramalho, jcr@di.uminho.pt
# * **Autor:** Amanda Maria de Melo Vieira, A88312
# * **Resumo:** Este trabalho tem como objetivo criar uma aplicação que demostre a representação gráfica de um quadrado centrado na origem com 10 unidades de lado.

# %%
# plotting the points
plt.plot(x,y, color='blue', linestyle='dashed', linewidth = 3,
         marker='o', markerfacecolor='red', markersize=12)

x=[5,5,-5,-5,5] 
y=[-5,5,5,-5,-5]

# setting x and y axis range
plt.ylim(-8,8)
plt.xlim(-8,8)
 
# naming the x axis
plt.xlabel('Eixo das Abcissas')
# naming the y axis
plt.ylabel('Eixo das Ordenadas')
 
# Dar um título ao gráfico
plt.title('Gráfico Polinomial')
 
# Função que desenha o gráfico
plt.show()
